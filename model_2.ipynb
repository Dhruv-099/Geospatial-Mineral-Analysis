# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from pycaret.classification import *

# %%
hydrothermal_deposits_df = pd.read_csv("Hydrothermal_deposits.csv")
porphyry_deposits_df = pd.read_csv("Phorphy_deposits.csv")
sedex_deposits_df = pd.read_csv("Sedex _Deposits.csv")
vms_deposits_df = pd.read_csv("VMS_Dataset.csv")
epithermal_deposits_df = pd.read_csv("epithermal_Deposists.csv")

# %%
hydrothermal_deposits_df['Deposit_Type'] = 'Hydrothermal'
porphyry_deposits_df['Deposit_Type'] = 'Porphyry'
sedex_deposits_df['Deposit_Type'] = 'Sedex'
vms_deposits_df['Deposit_Type'] = 'VMS'
epithermal_deposits_df['Deposit_Type'] = 'Epithermal'

# %%
# --- 1. Load and Clean Porphyry Data ---
# This file is mostly clean but has many empty cells and blank rows at the end.
porphyry_df = pd.read_csv('Phorphy_deposits.csv')
porphyry_df.dropna(how='all', inplace=True) # Drop rows where all values are missing
porphyry_df['Deposit_Type'] = 'Porphyry'
print("Porphyry data loaded and cleaned.")
# Out:
# Porphyry data loaded and cleaned.

# %%
# --- 2. Load and Clean SEDEX Data ---
# The column names have extra spaces around them.
sedex_df = pd.read_csv('Sedex _Deposits.csv')
sedex_df.columns = sedex_df.columns.str.strip() # Remove leading/trailing spaces from headers
sedex_df['Deposit_Type'] = 'SEDEX'
print("SEDEX data loaded and cleaned.")
# Out:
# SEDEX data loaded and cleaned.

# %%
# --- 3. Load and Clean VMS Data ---
# This file has junk rows at the beginning and empty columns/rows at the end.
# We skip the first two rows which are not data.
vms_df = pd.read_csv('VMS_Dataset.csv', header=1)

# The junk row of numbers ('0.005', '0.010'...) is now the first data row (at index 0).
# We must drop it by its index.
vms_df.drop(vms_df.index[0], inplace=True)

# Now, we proceed with the other cleaning steps for this file.
vms_df = vms_df.iloc[:, :-2] # Drop the last two completely empty columns
vms_df.dropna(how='all', inplace=True) # Drop empty rows from the end
vms_df['Deposit_Type'] = 'VMS'
print("VMS data loaded and cleaned.")
# Out:
# VMS data loaded and cleaned.

# %%
# --- 4. Load and Clean Epithermal Data ---
# The first column has a very messy name. We will rename it to 'Fe'.
epithermal_df = pd.read_csv('epithermal_Deposists.csv')
# Rename the first column to 'Fe' for consistency.
epithermal_df.rename(columns={epithermal_df.columns[0]: 'Fe'}, inplace=True)
epithermal_df['Deposit_Type'] = 'Epithermal'
print("Epithermal data loaded and cleaned.")
# Out:
# Epithermal data loaded and cleaned.

# %%
hydrothermal_df = pd.read_csv('Hydrothermal_deposits.csv', header=0)
hydrothermal_df = hydrothermal_df.iloc[2:].reset_index(drop=True)
hydrothermal_df.columns = hydrothermal_df.columns.str.strip()
hydrothermal_df.replace('b.d', np.nan, inplace=True)
hydrothermal_df.drop(columns=['Analysis spots'], inplace=True)
hydrothermal_df.dropna(thresh=5, inplace=True)
hydrothermal_df['Deposit_Type'] = 'Hydrothermal'
print("Hydrothermal data loaded and cleaned.")
# Out:
# Hydrothermal data loaded and cleaned.

# %%
# --- 6. Combine all DataFrames ---
# Now, we combine them. Because they don't share all the same columns,
# pandas will create NaN values where a column from one file doesn't exist in another.
# This is expected and we will handle it in the next phase.
master_df = pd.concat([
    porphyry_df,
    sedex_df,
    vms_df,
    epithermal_df,
    hydrothermal_df
], ignore_index=True)

master_df.drop(columns=['Total'], inplace=True, errors='ignore')

# %%
# Convert all possible columns to numeric types. Errors will become NaN.
for col in master_df.columns:
    if col != 'Deposit_Type':
        master_df[col] = pd.to_numeric(master_df[col], errors='coerce')

print("\nAll data combined into 'master_df'.")

# --- 7. Final Inspection ---
print("\nMaster DataFrame Info (shows data types and non-null counts):")
master_df.info()

print("\nShape of the final combined DataFrame:", master_df.shape)

print("\nNumber of samples per deposit type:")
print(master_df['Deposit_Type'].value_counts())

# Save the cleaned master DataFrame to a new CSV to use in the next phases.
master_df.to_csv('master_mineral_data.csv', index=False)
print("\nCleaned master DataFrame saved to 'master_mineral_data.csv'")
# Out:
# All data combined into 'master_df'.
#
# Master DataFrame Info (shows data types and non-null counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   P             130 non-null    float64
#  1   Ti            375 non-null    float64
#  2   Cr            459 non-null    float64
#  3   Co            614 non-null    float64
#  4   Ni            615 non-null    float64
#  5   Cu            613 non-null    float64
#  6   Zn            615 non-null    float64
#  7   As            610 non-null    float64
#  8   Se            594 non-null    float64
#  9   Rb            202 non-null    float64
#  10  Sr            221 non-null    float64
#  11  Mo            356 non-null    float64
#  12  Ag            605 non-null    float64
#  13  Sb            568 non-null    float64
#  14  La            74 non-null     float64
#  15  Ce            78 non-null     float64
#  16  Pr            73 non-null     float64
#  17  Nd            83 non-null     float64
#  18  Sm            88 non-null     float64
#  19  Eu            56 non-null     float64
#  20  Gd            64 non-null     float64
#  21  Tb            55 non-null     float64
#  22  Dy            51 non-null     float64
#  23  Ho            62 non-null     float64
#  24  Er            49 non-null     float64
#  25  Tm            50 non-null     float64
#  26  Yb            60 non-null     float64
#  27  Lu            63 non-null     float64
#  28  W             284 non-null    float64
#  29  Bi            493 non-null    float64
#  30  Pb            615 non-null    float64
#  31  Deposit_Type  615 non-null    object
#  32  Fe            337 non-null    float64
#  33  Ge            210 non-null    float64
#  34  Te            330 non-null    float64
#  35  Au            479 non-null    float64
#  36  S             210 non-null    float64
#  37  Total         108 non-null    float64
#  38  V             250 non-null    float64
#  39  Mn            250 non-null    float64
#  40  Cd            248 non-null    float64
#  41  Sn            250 non-null    float64
#  42  Ba            248 non-null    float64
#  43  Tl            247 non-null    float64
#  44  Na            102 non-null    float64
#  45  Mg            102 non-null    float64
#  46  Al            101 non-null    float64
#  47  Si            102 non-null    float64
#  48  K             102 non-null    float64
#  49  Ca            97 non-null     float64
#  50  Ga            99 non-null     float64
#  51  In            99 non-null     float64
# dtypes: float64(51), object(1)
# memory usage: 250.0+ KB
#
# Shape of the final combined DataFrame: (615, 52)
#
# Number of samples per deposit type:
# Deposit_Type
# VMS             148
# Porphyry        130
# Epithermal      127
# SEDEX           108
# Hydrothermal    102
# Name: count, dtype: int64
#
# Cleaned master DataFrame saved to 'master_mineral_data.csv'

# %%
# Load the master dataset you created in Phase 1
master_df = pd.read_csv('master_mineral_data.csv')

print("Data loaded successfully.")
print("Shape of the dataset:", master_df.shape)
master_df.head()
# Out:
# Data loaded successfully.
# Shape of the dataset: (615, 52)
#           P      Ti      Cr         Co        Ni      Cu      Zn        As  \
# 0   90.5170  6.2105  1.1737  4116.7326   81.4529  0.2898  1.4136  257.9315
# 1  109.9606  4.9979  0.8826  2384.6766  224.7375  3.0433  2.4632   15.0667
# 2  118.3088  6.5557  0.2061  1275.4860   52.7874  0.1746  1.6272   24.1259
# 3  113.1241  5.1639  1.6516  1245.6729  194.2875  0.2385  1.4484    8.9044
# 4   77.8263  5.1099  4.4611  1814.9775  175.4654  0.8483  2.0768    3.9935
#
#         Se      Rb  ...  Ba  Tl  Na  Mg  Al  Si   K  Ca  Ga  In
# 0      NaN  0.5063  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1  19.4082  3.4249  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2  25.6262  0.4048  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3  28.5042  0.5627  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4  11.5739  0.0165  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 52 columns]

# %%
# Separate 85% for training/validation and 15% for the final hold-out test set
# We use 'stratify' to ensure the proportion of each deposit type is the same in both sets
data_for_pycaret, holdout_test_set = train_test_split(
    master_df, 
    test_size=0.15, 
    random_state=42, 
    stratify=master_df['Deposit_Type']
)

print("Data for PyCaret (Training):", data_for_pycaret.shape)
print("Hold-out Test Set:", holdout_test_set.shape)
# Out:
# Data for PyCaret (Training): (522, 52)
# Hold-out Test Set: (93, 52)

# %%
# Initialize the PyCaret classification environment
# session_id is a random seed for reproducibility
clf_setup = setup(
    data=data_for_pycaret, 
    target='Deposit_Type', 
    numeric_imputation='median',  # Use median to fill missing numbers
    session_id=123
)
# Out:
# <style type="text/css">
# #T_03f50_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_03f50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03f50_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_03f50_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03f50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03f50_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_03f50_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03f50_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_03f50_row1_col1" class="data row1 col1" >Deposit_Type</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03f50_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_03f50_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03f50_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_03f50_row3_col1" class="data row3 col1" >Epithermal: 0, Hydrothermal: 1, Porphyry: 2, SEDEX: 3, VMS: 4</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03f50_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_03f50_row4_col1" class="data row4 col1" >(522, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03f50_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_03f50_row5_col1" class="data row5 col1" >(522, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03f50_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_03f50_row6_col1" class="data row6 col1" >(365, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03f50_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_03f50_row7_col1" class="data row7 col1" >(157, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03f50_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_03f50_row8_col1" class="data row8 col1" >51</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03f50_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_03f50_row9_col1" class="data row9 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_03f50_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_03f50_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_03f50_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_03f50_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_03f50_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_03f50_row12_col1" class="data row12 col1" >median</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_03f50_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_03f50_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_03f50_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_03f50_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_03f50_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_03f50_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_03f50_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_03f50_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_03f50_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_03f50_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_03f50_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_03f50_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_03f50_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_03f50_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_03f50_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_03f50_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_03f50_row20_col1" class="data row20 col1" >bf0d</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This command trains and evaluates multiple models, then returns the best one.
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4ada8 th {
#   text-align: left;
# }
# #T_4ada8_row0_col0, #T_4ada8_row1_col0, #T_4ada8_row2_col0, #T_4ada8_row3_col0, #T_4ada8_row4_col0, #T_4ada8_row4_col1, #T_4ada8_row4_col2, #T_4ada8_row4_col3, #T_4ada8_row4_col4, #T_4ada8_row4_col5, #T_4ada8_row4_col6, #T_4ada8_row4_col7, #T_4ada8_row5_col0, #T_4ada8_row5_col1, #T_4ada8_row5_col2, #T_4ada8_row5_col3, #T_4ada8_row5_col4, #T_4ada8_row5_col5, #T_4ada8_row5_col6, #T_4ada8_row5_col7, #T_4ada8_row6_col0, #T_4ada8_row6_col1, #T_4ada8_row6_col2, #T_4ada8_row6_col3, #T_4ada8_row6_col4, #T_4ada8_row6_col5, #T_4ada8_row6_col6, #T_4ada8_row6_col7, #T_4ada8_row7_col0, #T_4ada8_row7_col1, #T_4ada8_row7_col2, #T_4ada8_row7_col3, #T_4ada8_row7_col4, #T_4ada8_row7_col5, #T_4ada8_row7_col6, #T_4ada8_row7_col7, #T_4ada8_row8_col0, #T_4ada8_row8_col1, #T_4ada8_row8_col2, #T_4ada8_row8_col3, #T_4ada8_row8_col4, #T_4ada8_row8_col5, #T_4ada8_row8_col6, #T_4ada8_row8_col7, #T_4ada8_row9_col0, #T_4ada8_row9_col1, #T_4ada8_row9_col2, #T_4ada8_row9_col3, #T_4ada8_row9_col4, #T_4ada8_row9_col5, #T_4ada8_row9_col6, #T_4ada8_row9_col7, #T_4ada8_row10_col0, #T_4ada8_row10_col1, #T_4ada8_row10_col2, #T_4ada8_row10_col3, #T_4ada8_row10_col4, #T_4ada8_row10_col5, #T_4ada8_row10_col6, #T_4ada8_row10_col7, #T_4ada8_row11_col0, #T_4ada8_row11_col1, #T_4ada8_row11_col2, #T_4ada8_row11_col3, #T_4ada8_row11_col4, #T_4ada8_row11_col5, #T_4ada8_row11_col6, #T_4ada8_row11_col7, #T_4ada8_row12_col0, #T_4ada8_row12_col1, #T_4ada8_row12_col2, #T_4ada8_row12_col3, #T_4ada8_row12_col4, #T_4ada8_row12_col5, #T_4ada8_row12_col6, #T_4ada8_row12_col7, #T_4ada8_row13_col0, #T_4ada8_row13_col1, #T_4ada8_row13_col2, #T_4ada8_row13_col3, #T_4ada8_row13_col4, #T_4ada8_row13_col5, #T_4ada8_row13_col6, #T_4ada8_row13_col7, #T_4ada8_row14_col0, #T_4ada8_row14_col1, #T_4ada8_row14_col2, #T_4ada8_row14_col3, #T_4ada8_row14_col4, #T_4ada8_row14_col5, #T_4ada8_row14_col6, #T_4ada8_row14_col7, #T_4ada8_row15_col0, #T_4ada8_row15_col1, #T_4ada8_row15_col2, #T_4ada8_row15_col3, #T_4ada8_row15_col4, #T_4ada8_row15_col5, #T_4ada8_row15_col6, #T_4ada8_row15_col7 {
#   text-align: left;
# }
# #T_4ada8_row0_col1, #T_4ada8_row0_col2, #T_4ada8_row0_col3, #T_4ada8_row0_col4, #T_4ada8_row0_col5, #T_4ada8_row0_col6, #T_4ada8_row0_col7, #T_4ada8_row1_col1, #T_4ada8_row1_col2, #T_4ada8_row1_col3, #T_4ada8_row1_col4, #T_4ada8_row1_col5, #T_4ada8_row1_col6, #T_4ada8_row1_col7, #T_4ada8_row2_col1, #T_4ada8_row2_col2, #T_4ada8_row2_col3, #T_4ada8_row2_col4, #T_4ada8_row2_col5, #T_4ada8_row2_col6, #T_4ada8_row2_col7, #T_4ada8_row3_col1, #T_4ada8_row3_col2, #T_4ada8_row3_col3, #T_4ada8_row3_col4, #T_4ada8_row3_col5, #T_4ada8_row3_col6, #T_4ada8_row3_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4ada8_row0_col8, #T_4ada8_row1_col8, #T_4ada8_row2_col8, #T_4ada8_row3_col8, #T_4ada8_row4_col8, #T_4ada8_row5_col8, #T_4ada8_row6_col8, #T_4ada8_row7_col8, #T_4ada8_row8_col8, #T_4ada8_row9_col8, #T_4ada8_row10_col8, #T_4ada8_row11_col8, #T_4ada8_row12_col8, #T_4ada8_row14_col8, #T_4ada8_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4ada8_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4ada8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ada8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4ada8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4ada8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4ada8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4ada8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4ada8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4ada8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4ada8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4ada8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ada8_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_4ada8_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_4ada8_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_4ada8_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_4ada8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_4ada8_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_4ada8_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_4ada8_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_4ada8_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_4ada8_row0_col8" class="data row0 col8" >0.1310</td>
#     </tr>
#     <tr>
#       <th id="T_4ada8_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_4ada8_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_4ada8_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_4ada8_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_4ada8_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_4ada8_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_4ada8_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_4ada8_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_4ada8_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_4ada8_row1_col8" class="data row1 col8" >0.1130</td>
#     </tr>
#     <tr>
#       <th id="T_4ada8_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_4ada8_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4ada8_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_4ada8_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_4ada8_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_4ada8_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_4ada8_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_4ada8_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_4ada8_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_4ada8_row2_col8" class="data row2 col8" >248.6630</td>
#     </tr>
#     <tr>
#       <th id="T_4ada8_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_4ada8_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_4ada8_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_4ada8_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_4ada8_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_4ada8_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_4ada8_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_4ada8_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_4ada8_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_4ada8_row3_col8" class="data row3 col8" >32.0410</td>
#     </tr>
#     <tr>
#       <th id="T_4ada8_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_4ada8_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_4ada8_row4_col1" class="data row4 col1" >0.9972</td>
#       <td id="T_4ada8_row4_col2" class="data row4 col2" >0.9983</td>
#       <td id="T_4ada8_row4_col3" class="data row4 col3" >0.9972</td>
#       <td id="T_4ada8_row4_col4" class="data row4 col4" >0.9976</td>
#       <td id="T_4ada8_row4_col5" class="data row4 col5" >0.9972</td>
#       <td id="T_4ada8_row4_col6" class="data row4 col6" >0.9965</td>
#       <td id="T_4ada8_row4_col7" class="data row4 col7" >0.9966</td>
#       <td id="T_4ada8_row4_col8" class="data row4 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_4ada8_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_4ada8_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_4ada8_row5_col1" class="data row5 col1" >0.9945</td>
#       <td id="T_4ada8_row5_col2" class="

# %%
# Create a Random Forest model instance
rf_model = create_model('rf')

# Automatically tune the hyperparameters of the Random Forest model
tuned_rf_model = tune_model(rf_model)
# Out:
# <style type="text/css">
# #T_282ac_row10_col0, #T_282ac_row10_col1, #T_282ac_row10_col2, #T_282ac_row10_col3, #T_282ac_row10_col4, #T_282ac_row10_col5, #T_282ac_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_282ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_282ac_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_282ac_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_282ac_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_282ac_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_282ac_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_282ac_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_282ac_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_282ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_282ac_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_282ac_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_282ac_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_282ac_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_282ac_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_282ac_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_282ac_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_282ac_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_282ac_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_282ac_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_282ac_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_282ac_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_282ac_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_282ac_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_282ac_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_282ac_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_282ac_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_282ac_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_282ac_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_282ac_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_282ac_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_282ac_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_282ac_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_282ac_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_282ac_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_282ac_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_282ac_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_282ac_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_282ac_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_282ac_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_282ac_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_282ac_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_282ac_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_282ac_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_282ac_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_282ac_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_282ac_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_282ac_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_282ac_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_282ac_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_282ac_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_282ac_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_282ac_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_282ac_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_282ac_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_282ac_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_282ac_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_282ac_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_282ac_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_282ac_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_282ac_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_282ac_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_282ac_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_282ac_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_282ac_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_282ac_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_282ac_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_282ac_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_282ac_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_282ac_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_282ac_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_282ac_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_282ac_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_282ac_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_282ac_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_282ac_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_282ac_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_282ac_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_282ac_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_282ac_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_282ac_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_282ac_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_282ac_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_282ac_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_282ac_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_282ac_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_282ac_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_282ac_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_282ac_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_282ac_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_282ac_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_282ac_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_282ac_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_a6004_row10_col0, #T_a6004_row10_col1, #T_a6004_row10_col2, #T_a6004_row10_col3, #T_a6004_row10_col4, #T_a6004_row10_col5, #T_a6004_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6004">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6004_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6004_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6004_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6004_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6004_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a6004_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a6004_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6004_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6004_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_a6004_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a6004_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_a6004_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_a6004_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_a6004_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_a6004_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6004_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_a6004_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_a6004_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_a6004_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_a6004_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_a6004_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_a6004_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6004_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_a6004_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_a6004_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_a6004_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_a6004_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_a6004_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_a6004_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6004_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_a6004_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_a6004_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_a6004_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_a6004_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_a6004_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_a6004_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6004_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_a6004_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_a6004_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_a6004_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_a6004_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_a6004_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_a6004_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6004_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_a6004_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_a6004_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_a6004_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_a6004_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_a6004_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_a6004_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6004_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_a6004_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_a6004_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_a6004_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_a6004_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_a6004_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_a6004_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6004_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_a6004_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_a6004_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_a6004_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_a6004_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_a6004_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_a6004_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6004_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_a6004_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_a6004_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_a6004_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_a6004_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_a6004_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_a6004_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6004_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_a6004_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_a6004_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_a6004_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_a6004_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_a6004_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_a6004_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a6004_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_a6004_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_a6004_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_a6004_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_a6004_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_a6004_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_a6004_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a6004_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a6004_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_a6004_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_a6004_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_a6004_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_a6004_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Finalize the model (retrains it on the full training dataset)
final_model = finalize_model(tuned_rf_model)

# Use the final model to make predictions on the hold-out test data
predictions = predict_model(final_model, data=holdout_test_set)

# The 'predictions' DataFrame will show the original test data with new columns
# for the predicted label and confidence score. The accuracy score printed here
# is the most important one.
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa0a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa0a1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fa0a1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fa0a1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fa0a1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fa0a1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fa0a1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fa0a1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fa0a1_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa0a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa0a1_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_fa0a1_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_fa0a1_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_fa0a1_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_fa0a1_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_fa0a1_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_fa0a1_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_fa0a1_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#            P      Ti      Cr           Co       Ni          Cu         Zn  \
# 119  61.3186  5.4394  0.8626  1821.818604  89.3479   41.268799  63.079899
# 261      NaN  7.1100  3.1800    19.610001   2.8700   51.360001   8.020000
# 489      NaN     NaN     NaN     0.010000   0.1800    0.100000   0.160000
# 266      NaN  6.4100  5.4200     1.540000   0.8300  227.899994   2.820000
# 400      NaN     NaN     NaN     0.010000   0.2100    0.110000   0.180000
#
#           As          Se      Rb  ...  Mg  Al  Si   K  Ca  Ga  In  \
# 119   1.1782   18.194901  0.0641  ... NaN NaN NaN NaN NaN NaN NaN
# 261   8.0300  222.910004     NaN  ... NaN NaN NaN NaN NaN NaN NaN
# 489   0.2600    0.470000     NaN  ... NaN NaN NaN NaN NaN NaN NaN
# 266  14.4400  310.119995     NaN  ... NaN NaN NaN NaN NaN NaN NaN
# 400   0.2800    0.330000     NaN  ... NaN NaN NaN NaN NaN NaN NaN
#
#      Deposit_Type  prediction_label  prediction_score
# 119      Porphyry          Porphyry              0.99
# 261           VMS               VMS              1.00
# 489    Epithermal        Epithermal              1.00
# 266           VMS               VMS              0.99
# 400    Epithermal        Epithermal              1.00
#
# [5 rows x 54 columns]

# %%
# Save the final model pipeline to a file
save_model(final_model, 'mineral_deposit_classifier')

print("Model saved as 'mineral_deposit_classifier.pkl'")
# Out:
# Transformation Pipeline and Model Successfully Saved
# Model saved as 'mineral_deposit_classifier.pkl'
